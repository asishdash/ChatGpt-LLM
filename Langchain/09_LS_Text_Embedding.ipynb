# %% [markdown]
# <a href="https://colab.research.google.com/github/asishdash/ChatGpt-LLM/blob/main/Langchain/09_LS_Text_Embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Text Embeddings

# %%
# !pip install openai
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 58.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.1.1
#     Uninstalling pydantic-2.1.1:
#       Successfully uninstalled pydantic-2.1.1
# ...

# %%
# !pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 8.7 MB/s eta 0:00:00
# ...

# %%
import openai

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
import os

# %%
embeddings = OpenAIEmbeddings() #MEMORY

# %%
text = "Some normal text to send to OpenAI to be embedded into a N dimensional vector"

# %%
embedded_text = embeddings.embed_query(text)

# %%
type(embedded_text)
# Out:
# list

# %%
embedded_text
# Out:
# [-0.01015595303177178,
#  -0.004021873059664566,
#  0.003381701041414121,
#  0.023494684062123048,
#  0.02271345719239369,
#  0.02047104487034028,
#  -0.015928353431861542,
#  0.00486096905207218,
#  -0.039553241972272814,
#  -0.018995394116407053,
#  0.010090850792627667,
#  0.03460547179732022,
#  -0.00797864388018502,
#  -0.0056566635517170515,
#  0.015089258836437731,
#  0.018980926952152803,
#  0.004105059719787756,
#  0.013020453416757826,
#  0.033187689700403984,
#  0.0013427342644239165,
#  -0.020167234421001087,
#  -0.013866782525631295,
#  -0.0018698816783533714,
#  0.005175629874602059,
#  -0.01954514635806845,
#  -0.01148693307448507,
#  0.025404351606328767,
#  -0.026460454596888824,
#  -0.0036095588784185164,
#  -0.022178172114986537,
#  0.033390229999963446,
#  -0.0003533154225408431,
#  0.006495759544124666,
#  -0.01600068925313278,
#  -0.01773675082628753,
#  0.017621013512253553,
#  -0.002956727858614971,
#  -0.011002283071967786,
#  0.041433973325324974,
# ...

# %% [markdown]
# ## Embed Documents

# %%
from langchain.document_loaders import CSVLoader

# %%
loader = CSVLoader('/content/some_data/penguins.csv')

# %%
data = loader.load()

# %%
type(data)
# Out:
# list

# %%
type(data[0])
# Out:
# langchain.schema.document.Document

# %%
# embedded_docs = embeddings.embed_documents(data)

# %%
embedded_docs = embeddings.embed_documents([text.page_content for text in data])

# %%
len(embedded_docs)
# Out:
# 344

# %%
# embedded_docs[0]
